# %% [markdown]
# ## 1.Installing Pycaret

# %%
#pip install pycaret

# %% [markdown]
# ## 2.Import necessary libraries

# %%
import pandas as pd
from pycaret.regression import *

# %% [markdown]
# ## Example Code: Startup Profit prediction with PyCaret

# %% [markdown]
# ## 3.Importing 50 Startup dataset

# %%
data = pd.read_csv('50_Startups.csv')
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %% [markdown]
# ## 4.Initialize the setup
# * The `setup()` function automatically preprocesses the data and splits it into training and testing sets.

# %%
regression = setup(data, target='Profit', session_id=123)
regression
# Out:
# <style type="text/css">
# #T_f2e41_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f2e41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2e41_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f2e41_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2e41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2e41_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f2e41_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2e41_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f2e41_row1_col1" class="data row1 col1" >Profit</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2e41_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f2e41_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2e41_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f2e41_row3_col1" class="data row3 col1" >(50, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2e41_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f2e41_row4_col1" class="data row4 col1" >(50, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f2e41_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f2e41_row5_col1" class="data row5 col1" >(35, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f2e41_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f2e41_row6_col1" class="data row6 col1" >(15, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f2e41_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f2e41_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f2e41_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_f2e41_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f2e41_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_f2e41_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f2e41_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_f2e41_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f2e41_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_f2e41_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f2e41_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_f2e41_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f2e41_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_f2e41_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f2e41_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_f2e41_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f2e41_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_f2e41_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f2e41_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_f2e41_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f2e41_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_f2e41_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f2e41_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_f2e41_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f2e41_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_f2e41_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f2e41_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_f2e41_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f2e41_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f2e41_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_f2e41_row21_col1" class="data row21 col1" >a5fa</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5.Compare and evaluate the different models
# * Next, we use the `compare_models()` function to compare and evaluate different regression models using default settings.
# * PyCaret automatically evaluates models using various metrics, such as R-squared, Mean Absolute Error (MAE), and Root Mean Squared Error (RMSE).

# %%
best_model = compare_models()
best_model
# Out:
# <style type="text/css">
# #T_585fa th {
#   text-align: left;
# }
# #T_585fa_row0_col0, #T_585fa_row0_col1, #T_585fa_row0_col2, #T_585fa_row0_col3, #T_585fa_row0_col5, #T_585fa_row0_col6, #T_585fa_row1_col0, #T_585fa_row1_col1, #T_585fa_row1_col2, #T_585fa_row1_col3, #T_585fa_row1_col4, #T_585fa_row1_col5, #T_585fa_row2_col0, #T_585fa_row2_col4, #T_585fa_row2_col6, #T_585fa_row3_col0, #T_585fa_row3_col1, #T_585fa_row3_col2, #T_585fa_row3_col3, #T_585fa_row3_col4, #T_585fa_row3_col5, #T_585fa_row3_col6, #T_585fa_row4_col0, #T_585fa_row4_col1, #T_585fa_row4_col2, #T_585fa_row4_col3, #T_585fa_row4_col4, #T_585fa_row4_col5, #T_585fa_row4_col6, #T_585fa_row5_col0, #T_585fa_row5_col1, #T_585fa_row5_col2, #T_585fa_row5_col3, #T_585fa_row5_col4, #T_585fa_row5_col5, #T_585fa_row5_col6, #T_585fa_row6_col0, #T_585fa_row6_col1, #T_585fa_row6_col2, #T_585fa_row6_col3, #T_585fa_row6_col4, #T_585fa_row6_col5, #T_585fa_row6_col6, #T_585fa_row7_col0, #T_585fa_row7_col1, #T_585fa_row7_col2, #T_585fa_row7_col3, #T_585fa_row7_col4, #T_585fa_row7_col5, #T_585fa_row7_col6, #T_585fa_row8_col0, #T_585fa_row8_col1, #T_585fa_row8_col2, #T_585fa_row8_col3, #T_585fa_row8_col4, #T_585fa_row8_col5, #T_585fa_row8_col6, #T_585fa_row9_col0, #T_585fa_row9_col1, #T_585fa_row9_col2, #T_585fa_row9_col3, #T_585fa_row9_col4, #T_585fa_row9_col5, #T_585fa_row9_col6, #T_585fa_row10_col0, #T_585fa_row10_col1, #T_585fa_row10_col2, #T_585fa_row10_col3, #T_585fa_row10_col4, #T_585fa_row10_col5, #T_585fa_row10_col6, #T_585fa_row11_col0, #T_585fa_row11_col1, #T_585fa_row11_col2, #T_585fa_row11_col3, #T_585fa_row11_col4, #T_585fa_row11_col5, #T_585fa_row11_col6, #T_585fa_row12_col0, #T_585fa_row12_col1, #T_585fa_row12_col2, #T_585fa_row12_col3, #T_585fa_row12_col4, #T_585fa_row12_col5, #T_585fa_row12_col6, #T_585fa_row13_col0, #T_585fa_row13_col1, #T_585fa_row13_col2, #T_585fa_row13_col3, #T_585fa_row13_col4, #T_585fa_row13_col5, #T_585fa_row13_col6, #T_585fa_row14_col0, #T_585fa_row14_col1, #T_585fa_row14_col2, #T_585fa_row14_col3, #T_585fa_row14_col4, #T_585fa_row14_col5, #T_585fa_row14_col6, #T_585fa_row15_col0, #T_585fa_row15_col1, #T_585fa_row15_col2, #T_585fa_row15_col3, #T_585fa_row15_col4, #T_585fa_row15_col5, #T_585fa_row15_col6, #T_585fa_row16_col0, #T_585fa_row16_col1, #T_585fa_row16_col2, #T_585fa_row16_col3, #T_585fa_row16_col4, #T_585fa_row16_col5, #T_585fa_row16_col6, #T_585fa_row17_col0, #T_585fa_row17_col1, #T_585fa_row17_col2, #T_585fa_row17_col3, #T_585fa_row17_col4, #T_585fa_row17_col5, #T_585fa_row17_col6, #T_585fa_row18_col0, #T_585fa_row18_col1, #T_585fa_row18_col2, #T_585fa_row18_col3, #T_585fa_row18_col4, #T_585fa_row18_col5, #T_585fa_row18_col6 {
#   text-align: left;
# }
# #T_585fa_row0_col4, #T_585fa_row1_col6, #T_585fa_row2_col1, #T_585fa_row2_col2, #T_585fa_row2_col3, #T_585fa_row2_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_585fa_row0_col7, #T_585fa_row1_col7, #T_585fa_row2_col7, #T_585fa_row3_col7, #T_585fa_row4_col7, #T_585fa_row5_col7, #T_585fa_row6_col7, #T_585fa_row7_col7, #T_585fa_row8_col7, #T_585fa_row9_col7, #T_585fa_row10_col7, #T_585fa_row11_col7, #T_585fa_row12_col7, #T_585fa_row13_col7, #T_585fa_row14_col7, #T_585fa_row15_col7, #T_585fa_row17_col7, #T_585fa_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_585fa_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_585fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_585fa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_585fa_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_585fa_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_585fa_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_585fa_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_585fa_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_585fa_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_585fa_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_585fa_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_585fa_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_585fa_row0_col1" class="data row0 col1" >8439.4910</td>
#       <td id="T_585fa_row0_col2" class="data row0 col2" >151995494.0469</td>
#       <td id="T_585fa_row0_col3" class="data row0 col3" >10096.8588</td>
#       <td id="T_585fa_row0_col4" class="data row0 col4" >0.8889</td>
#       <td id="T_585fa_row0_col5" class="data row0 col5" >0.1706</td>
#       <td id="T_585fa_row0_col6" class="data row0 col6" >0.1561</td>
#       <td id="T_585fa_row0_col7" class="data row0 col7" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_585fa_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_585fa_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_585fa_row1_col1" class="data row1 col1" >7917.4076</td>
#       <td id="T_585fa_row1_col2" class="data row1 col2" >118977639.2000</td>
#       <td id="T_585fa_row1_col3" class="data row1 col3" >10203.3711</td>
#       <td id="T_585fa_row1_col4" class="data row1 col4" >0.8580</td>
#       <td id="T_585fa_row1_col5" class="data row1 col5" >0.1829</td>
#       <td id="T_585fa_row1_col6" class="data row1 col6" >0.1224</td>
#       <td id="T_585fa_row1_col7" class="data row1 col7" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_585fa_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_585fa_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_585fa_row2_col1" class="data row2 col1" >7759.7853</td>
#       <td id="T_585fa_row2_col2" class="data row2 col2" >117731002.5676</td>
#       <td id="T_585fa_row2_col3" class="data row2 col3" >9473.9148</td>
#       <td id="T_585fa_row2_col4" class="data row2 col4" >0.8562</td>
#       <td id="T_585fa_row2_col5" class="data row2 col5" >0.1525</td>
#       <td id="T_585fa_row2_col6" class="data row2 col6" >0.1384</td>
#       <td id="T_585fa_row2_col7" class="data row2 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_585fa_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_585fa_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_585fa_row3_col1" class="data row3 col1" >7873.8324</td>
#       <td id="T_585fa_row3_col2" class="data row3 col2" >118420853.3844</td>
#       <td id="T_585fa_row3_col3" class="data row3 col3" >9537.6059</td>
#       <td id="T_585fa_row3_col4" class="data row3 col4" >0.8465</td>
#       <td id="T_585fa_row3_col5" class="data row3 col5" >0.1529</td>
#       <td id="T_585fa_row3_col6" class="data row3 col6" >0.1389</td>
#       <td id="T_585fa_row3_col7" class="data row3 col7" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_585fa_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_585fa_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_585fa_row4_col1" class="data row4 col1" >8100.0242</td>
#       <td id="T_585fa_row4_col2" class="data row4 col2" >122473530.3254</td>
#       <td id="T_585fa_row4_col3" class="data row4 col3" >9725.4221</td>
#       <td id="T_585fa_row4_col4" class="data row4 col4" >0.8288</td>
#       <td id="T_585fa_row4_col5" class="data row4 col5" >0.1535</td>
#       <td id="T_585fa_row4_col6" class="data row4 col6" >0.1406</td>
#       <td id="T_585fa_row4_col7" class="data row4 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_585fa_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_585fa_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_585fa_row5_col1" class="data row5 col1" >8152.8553</td>
#       <td id="T_585fa_row5_col2" class="data row5 col2" >123518717.5635</td>
#       <td id="T_585fa_row5_col3" class="data row5 col3" >9771.9435</td>
#       <td id="T_585fa_row5_col4" class="data row5 col4" >0.8245</td>
#       <td id="T_585fa_row5_col5" class="d
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %% [markdown]
# ## 6.Tune Hyperparameters the best model
# * After identifying the best model, we fine-tune its hyperparameters using the `tune_model()` function.
# * PyCaret performs an automatic hyperparameter search to find the optimal combination.

# %%
tuned_model = tune_model(best_model)
tuned_model
# Out:
# <style type="text/css">
# #T_1cfc8_row10_col0, #T_1cfc8_row10_col1, #T_1cfc8_row10_col2, #T_1cfc8_row10_col3, #T_1cfc8_row10_col4, #T_1cfc8_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1cfc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1cfc8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1cfc8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1cfc8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1cfc8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1cfc8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1cfc8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cfc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1cfc8_row0_col0" class="data row0 col0" >41067.0075</td>
#       <td id="T_1cfc8_row0_col1" class="data row0 col1" >2028720304.1812</td>
#       <td id="T_1cfc8_row0_col2" class="data row0 col2" >45041.3177</td>
#       <td id="T_1cfc8_row0_col3" class="data row0 col3" >0.5425</td>
#       <td id="T_1cfc8_row0_col4" class="data row0 col4" >0.8726</td>
#       <td id="T_1cfc8_row0_col5" class="data row0 col5" >1.2692</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1cfc8_row1_col0" class="data row1 col0" >3015.6459</td>
#       <td id="T_1cfc8_row1_col1" class="data row1 col1" >16816551.6504</td>
#       <td id="T_1cfc8_row1_col2" class="data row1 col2" >4100.7989</td>
#       <td id="T_1cfc8_row1_col3" class="data row1 col3" >0.9071</td>
#       <td id="T_1cfc8_row1_col4" class="data row1 col4" >0.0320</td>
#       <td id="T_1cfc8_row1_col5" class="data row1 col5" >0.0257</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1cfc8_row2_col0" class="data row2 col0" >14260.7373</td>
#       <td id="T_1cfc8_row2_col1" class="data row2 col1" >481324328.6195</td>
#       <td id="T_1cfc8_row2_col2" class="data row2 col2" >21939.1050</td>
#       <td id="T_1cfc8_row2_col3" class="data row2 col3" >0.7453</td>
#       <td id="T_1cfc8_row2_col4" class="data row2 col4" >0.3959</td>
#       <td id="T_1cfc8_row2_col5" class="data row2 col5" >0.3281</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1cfc8_row3_col0" class="data row3 col0" >23583.0006</td>
#       <td id="T_1cfc8_row3_col1" class="data row3 col1" >785960623.7273</td>
#       <td id="T_1cfc8_row3_col2" class="data row3 col2" >28034.9893</td>
#       <td id="T_1cfc8_row3_col3" class="data row3 col3" >0.6410</td>
#       <td id="T_1cfc8_row3_col4" class="data row3 col4" >0.1992</td>
#       <td id="T_1cfc8_row3_col5" class="data row3 col5" >0.1737</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1cfc8_row4_col0" class="data row4 col0" >6518.6413</td>
#       <td id="T_1cfc8_row4_col1" class="data row4 col1" >63461869.6309</td>
#       <td id="T_1cfc8_row4_col2" class="data row4 col2" >7966.2959</td>
#       <td id="T_1cfc8_row4_col3" class="data row4 col3" >0.9057</td>
#       <td id="T_1cfc8_row4_col4" class="data row4 col4" >0.0704</td>
#       <td id="T_1cfc8_row4_col5" class="data row4 col5" >0.0592</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1cfc8_row5_col0" class="data row5 col0" >5083.5500</td>
#       <td id="T_1cfc8_row5_col1" class="data row5 col1" >32385171.6163</td>
#       <td id="T_1cfc8_row5_col2" class="data row5 col2" >5690.7971</td>
#       <td id="T_1cfc8_row5_col3" class="data row5 col3" >0.7305</td>
#       <td id="T_1cfc8_row5_col4" class="data row5 col4" >0.0626</td>
#       <td id="T_1cfc8_row5_col5" class="data row5 col5" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1cfc8_row6_col0" class="data row6 col0" >5795.0448</td>
#       <td id="T_1cfc8_row6_col1" class="data row6 col1" >45830140.0508</td>
#       <td id="T_1cfc8_row6_col2" class="data row6 col2" >6769.7962</td>
#       <td id="T_1cfc8_row6_col3" class="data row6 col3" >0.9256</td>
#       <td id="T_1cfc8_row6_col4" class="data row6 col4" >0.0594</td>
#       <td id="T_1cfc8_row6_col5" class="data row6 col5" >0.0508</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1cfc8_row7_col0" class="data row7 col0" >13838.1259</td>
#       <td id="T_1cfc8_row7_col1" class="data row7 col1" >212391019.3541</td>
#       <td id="T_1cfc8_row7_col2" class="data row7 col2" >14573.6413</td>
#       <td id="T_1cfc8_row7_col3" class="data row7 col3" >0.5548</td>
#       <td id="T_1cfc8_row7_col4" class="data row7 col4" >0.1381</td>
#       <td id="T_1cfc8_row7_col5" class="data row7 col5" >0.1341</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1cfc8_row8_col0" class="data row8 col0" >702.1902</td>
#       <td id="T_1cfc8_row8_col1" class="data row8 col1" >1231349.8169</td>
#       <td id="T_1cfc8_row8_col2" class="data row8 col2" >1109.6620</td>
#       <td id="T_1cfc8_row8_col3" class="data row8 col3" >0.9963</td>
#       <td id="T_1cfc8_row8_col4" class="data row8 col4" >0.0135</td>
#       <td id="T_1cfc8_row8_col5" class="data row8 col5" >0.0084</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1cfc8_row9_col0" class="data row9 col0" >19946.0405</td>
#       <td id="T_1cfc8_row9_col1" class="data row9 col1" >841606501.3523</td>
#       <td id="T_1cfc8_row9_col2" class="data row9 col2" >29010.4550</td>
#       <td id="T_1cfc8_row9_col3" class="data row9 col3" >0.6980</td>
#       <td id="T_1cfc8_row9_col4" class="data row9 col4" >0.1900</td>
#       <td id="T_1cfc8_row9_col5" class="data row9 col5" >0.1384</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1cfc8_row10_col0" class="data row10 col0" >13380.9984</td>
#       <td id="T_1cfc8_row10_col1" class="data row10 col1" >450972786.0000</td>
#       <td id="T_1cfc8_row10_col2" class="data row10 col2" >16423.6858</td>
#       <td id="T_1cfc8_row10_col3" class="data row10 col3" >0.7647</td>
#       <td id="T_1cfc8_row10_col4" class="data row10 col4" >0.2034</td>
#       <td id="T_1cfc8_row10_col5" class="data row10 col5" >0.2244</td>
#     </tr>
#     <tr>
#       <th id="T_1cfc8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_1cfc8_row11_col0" class="data row11 col0" >11646.2768</td>
#       <td id="T_1cfc8_row11_col1" class="data row11 col1" >607636496.4080</td>
#       <td id="T_1cfc8_row11_col2" class="data row11 col2" >13462.3672</td>
#       <td id="T_1cfc8_row11_col3" class="data row11 col3" >0.1531</td>
#       <td id="T_1cfc8_row11_col4" class="data row11 col4" >0.2476</td>
#       <td id="T_1cfc8_row11_col5" class="data row11 col5" >0.3595</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %% [markdown]
# ## 7.Evaluate the model performance
# * We then evaluate the performance of the tuned model using the `evaluate_model()` function.
# * PyCaret generates a comprehensive report with various evaluation metrics and visualizations.

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## 8.Make predictions on new data
# * To make predictions on new data, we load the new dataset, `new_data.csv`, and use the `predict_model()` function with the tuned model.

# %%
new_data = pd.read_csv('1000_Companies.csv')
predictions = predict_model(tuned_model, data=new_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5625d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5625d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5625d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5625d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5625d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5625d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5625d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5625d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5625d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5625d_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_5625d_row0_col1" class="data row0 col1" >5305.4327</td>
#       <td id="T_5625d_row0_col2" class="data row0 col2" >243313798.0882</td>
#       <td id="T_5625d_row0_col3" class="data row0 col3" >15598.5191</td>
#       <td id="T_5625d_row0_col4" class="data row0 col4" >0.8676</td>
#       <td id="T_5625d_row0_col5" class="data row0 col5" >0.0839</td>
#       <td id="T_5625d_row0_col6" class="data row0 col6" >0.0452</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 9.Save the model for future use
# * Finally, we save the tuned model using the `save_model()` function for future use.

# %%
save_model(tuned_model, 'Profit_prediction_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['R&D Spend', 'Administration',
#                                               'Marketing Spend'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['State'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['State'],
#                                      transformer=OneHotEncoder(cols=['State'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('trained_model',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=123))]),
#  'Profit_prediction_model.pkl')

# %% [markdown]
# ## 10.Conclusion
#
# PyCaret offers an accessible and efficient approach to utilizing machine learning for a wide range of tasks. With its extensive feature set and streamlined workflow, PyCaret enables users to quickly prototype and deploy machine learning models. Whether you are new to the field or an experienced data scientist, PyCaret can greatly simplify the machine learning process, allowing you to concentrate on extracting valuable insights from your data.
